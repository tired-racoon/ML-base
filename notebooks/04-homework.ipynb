# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score, precision_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.model_selection import cross_validate, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %% [markdown]
# ##Easy

# %%
merc_df = pd.read_csv('./cars/merc.csv')
merc_df
# Out:
#             model  year  price transmission  mileage fuelType  tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325  30.1
# ...           ...   ...    ...          ...      ...      ...  ...   ...
# 13114     C Class  2020  35999    Automatic      500   Diesel  145  55.4
# 13115     B Class  2020  24699    Automatic     2500   Diesel  145  55.4
# 13116   GLC Class  2019  30999    Automatic    11612   Diesel  145  41.5
# 13117   CLS Class  2019  37990    Automatic     2426   Diesel  145  45.6
# 13118     S Class  2019  54999    Automatic     2075   Diesel  145  52.3
#
#        engineSize
# 0             1.8
# 1             2.1
# 2             5.5
# 3             4.0
# 4             4.0
# ...           ...
# 13114         2.0
# 13115         2.0
# 13116         2.1
# 13117         2.0
# 13118         2.9
#
# [13119 rows x 9 columns]

# %%
num_cols = merc_df[['year', 'mileage', 'tax', 'mpg', 'engineSize']]
target = merc_df[['price']]
num_cols
# Out:
#        year  mileage  tax   mpg  engineSize
# 0      2005    63000  325  32.1         1.8
# 1      2017    27000   20  61.4         2.1
# 2      2016     6200  555  28.0         5.5
# 3      2016    16000  325  30.4         4.0
# 4      2016     4000  325  30.1         4.0
# ...     ...      ...  ...   ...         ...
# 13114  2020      500  145  55.4         2.0
# 13115  2020     2500  145  55.4         2.0
# 13116  2019    11612  145  41.5         2.1
# 13117  2019     2426  145  45.6         2.0
# 13118  2019     2075  145  52.3         2.9
#
# [13119 rows x 5 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(num_cols, target, train_size=0.8, random_state=0)

# %%
tree = DecisionTreeRegressor()
tree.fit(x_train, y_train)
train_prediction = tree.predict(x_train)
test_prediction = tree.predict(x_test)

train_accuracy = r2_score(train_prediction, y_train)
test_accuracy = r2_score(test_prediction, y_test)

print('Точность на обучающей выборке: ', train_accuracy)
print('Точность на тестовой выборке: ', test_accuracy)
tree.feature_importances_
# Out:
# Точность на обучающей выборке:  0.9956476537300872
# Точность на тестовой выборке:  0.8639807356654801
# array([0.08998877, 0.33600831, 0.03570568, 0.19070747, 0.34758977])

# %% [markdown]
# Исходя из здравого смысла и того, как модель выбирает значимость каждого из признаков, вытекает вывод: цена больше всего зависит от пробега и объема двигателя. Причины тоже легко понять: чем больше объем, тем мощнее двигатель, то есть автомобиль более быстрый и престижный. И наоборот, чем больше пробег, тем дешевле машина, поскольку выше ее износ.

# %% [markdown]
# ##Medium

# %%
import os

df = merc_df
for root, dirs, files in os.walk('./cars'):
    for file in files:
        if file not in ["unclean cclass.csv", "unclean focus.csv"] :
            buf = pd.read_csv('./cars' + os.sep + file)
            buf = buf.rename(columns = {'tax(£)':'tax'})  # change pounds into default currency
            #print(file, '\n', buf)
            df = pd.concat([df, buf], ignore_index = True)
df
# Out:
#             model  year  price transmission  mileage fuelType    tax   mpg  \
# 0             SLK  2005   5200    Automatic    63000   Petrol  325.0  32.1
# 1         S Class  2017  34948    Automatic    27000   Hybrid   20.0  61.4
# 2        SL CLASS  2016  49948    Automatic     6200   Petrol  555.0  28.0
# 3         G Class  2016  61948    Automatic    16000   Petrol  325.0  30.4
# 4         G Class  2016  73948    Automatic     4000   Petrol  325.0  30.1
# ...           ...   ...    ...          ...      ...      ...    ...   ...
# 121654        Eos  2012   5990       Manual    74000   Diesel  125.0  58.9
# 121655        Fox  2008   1799       Manual    88102   Petrol  145.0  46.3
# 121656        Fox  2009   1590       Manual    70000   Petrol  200.0  42.0
# 121657        Fox  2006   1250       Manual    82704   Petrol  150.0  46.3
# 121658        Fox  2007   2295       Manual    74000   Petrol  145.0  46.3
#
#         engineSize
# 0              1.8
# 1              2.1
# 2              5.5
# 3              4.0
# 4              4.0
# ...            ...
# 121654         2.0
# 121655         1.2
# 121656         1.4
# 121657         1.2
# 121658         1.2
#
# [121659 rows x 9 columns]

# %%
data = pd.get_dummies(df.drop('price', axis = 1), columns = ['model', 'transmission', 'fuelType'])
data = data.fillna(0)
target = df[['price']]
data
# Out:
#         year  mileage    tax   mpg  engineSize  model_ 1 Series  \
# 0       2005    63000  325.0  32.1         1.8            False
# 1       2017    27000   20.0  61.4         2.1            False
# 2       2016     6200  555.0  28.0         5.5            False
# 3       2016    16000  325.0  30.4         4.0            False
# 4       2016     4000  325.0  30.1         4.0            False
# ...      ...      ...    ...   ...         ...              ...
# 121654  2012    74000  125.0  58.9         2.0            False
# 121655  2008    88102  145.0  46.3         1.2            False
# 121656  2009    70000  200.0  42.0         1.4            False
# 121657  2006    82704  150.0  46.3         1.2            False
# 121658  2007    74000  145.0  46.3         1.2            False
#
#         model_ 2 Series  model_ 3 Series  model_ 4 Series  model_ 5 Series  \
# 0                 False            False            False            False
# 1                 False            False            False            False
# 2                 False            False            False            False
# 3                 False            False            False            False
# 4                 False            False            False            False
# ...                 ...              ...              ...              ...
# 121654            False            False            False            False
# 121655            False            False            False            False
# 121656            False            False            False            False
# 121657            False            False            False            False
# 121658            False            False            False            False
#
#         ...  model_230  transmission_Automatic  transmission_Manual  \
# 0       ...      False                    True                False
# 1       ...      False                    True                False
# 2       ...      False                    True                False
# 3       ...      False                    True                False
# 4       ...      False                    True                False
# ...     ...        ...                     ...                  ...
# 121654  ...      False                   False                 True
# 121655  ...      False                   False                 True
# 121656  ...      False                   False                 True
# 121657  ...      False                   False                 True
# 121658  ...      False                   False                 True
#
#         transmission_Other  transmission_Semi-Auto  fuelType_Diesel  \
# 0                    False                   False            False
# 1                    False                   False            False
# 2                    False                   False            False
# 3                    False                   False            False
# 4                    False                   False            False
# ...                    ...                     ...              ...
# 121654               False                   False             True
# 121655               False                   False            False
# 121656               False                   False            False
# 121657               False                   False            False
# 121658               False                   False            False
#
#         fuelType_Electric  fuelType_Hybrid  fuelType_Other  fuelType_Petrol
# 0                   False            False           False             True
# 1                   False             True           False            False
# 2                   False            False           False             True
# 3                   False            False           False             True
# 4                   False            False           False             True
# ...                   ...              ...             ...              ...
# 121654              False            False           False            False
# 121655              False            False           False             True
# 121656              False            False           False             True
# 121657              False            False           False             True
# 121658              False            False           False             True
#
# [121659 rows x 209 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, train_size=0.8, random_state=0)

# %%
tree = DecisionTreeRegressor()
tree.fit(x_train, y_train)
train_prediction = tree.predict(x_train)
test_prediction = tree.predict(x_test)

train_accuracy = r2_score(train_prediction, y_train)
test_accuracy = r2_score(test_prediction, y_test)

print('Точность на обучающей выборке: ', train_accuracy)
print('Точность на тестовой выборке: ', test_accuracy)
# Out:
# Точность на обучающей выборке:  0.9995619837364046
# Точность на тестовой выборке:  0.9509177173768018

# %%
tree.feature_importances_.argmax()
# Out:
# 201

# %%
list(data.keys())[201]
# Out:
# 'transmission_Manual'

# %% [markdown]
# Сделаем перебор параметров

# %%
params = {
    'splitter' : ['best', 'random'],
    'max_depth': [20, 40, 60, 80]
}

search = GridSearchCV(DecisionTreeRegressor(), params, refit = True)
search.fit(x_train, y_train)
search.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=80, splitter='random')

# %%
best  = search.best_estimator_
train_prediction = best.predict(x_train)
test_prediction = best.predict(x_test)

train_accuracy = r2_score(train_prediction, y_train)
test_accuracy = r2_score(test_prediction, y_test)

print('Точность на обучающей выборке: ', train_accuracy)
print('Точность на тестовой выборке: ', test_accuracy)
# Out:
# Точность на обучающей выборке:  0.9995617644670527
# Точность на тестовой выборке:  0.9609688001733079

# %% [markdown]
# Тяжелая артиллерия

# %%
x_train, x_test, y_train, y_test = train_test_split(df, target, train_size=0.8, random_state=0)

# %%
from catboost import CatBoostRegressor
forest = CatBoostRegressor(cat_features = ['model', 'transmission', 'fuelType'], max_depth = 9, iterations = 100) 
forest.fit(x_train, y_train)            # I heard that this is the best way to feed cat_cols into catboost
train_prediction = forest.predict(x_train)
test_prediction = forest.predict(x_test)

train_accuracy = r2_score(train_prediction, y_train)
test_accuracy = r2_score(test_prediction, y_test)

print('Точность на обучающей выборке: ', train_accuracy)
print('Точность на тестовой выборке: ', test_accuracy)
# Out:
# Learning rate set to 0.5
# 0:	learn: 5534.6322340	total: 259ms	remaining: 25.7s
# 1:	learn: 3182.2828037	total: 344ms	remaining: 16.8s
# 2:	learn: 1982.0104652	total: 433ms	remaining: 14s
# 3:	learn: 1463.3372902	total: 516ms	remaining: 12.4s
# 4:	learn: 1265.6291700	total: 602ms	remaining: 11.4s
# 5:	learn: 1149.0161743	total: 686ms	remaining: 10.8s
# 6:	learn: 1004.8419714	total: 778ms	remaining: 10.3s
# 7:	learn: 938.7073354	total: 861ms	remaining: 9.9s
# 8:	learn: 872.6824937	total: 953ms	remaining: 9.64s
# 9:	learn: 810.9413132	total: 1.04s	remaining: 9.34s
# 10:	learn: 775.9248125	total: 1.13s	remaining: 9.15s
# 11:	learn: 731.7638491	total: 1.22s	remaining: 8.93s
# 12:	learn: 680.5662418	total: 1.31s	remaining: 8.75s
# 13:	learn: 677.1249496	total: 1.39s	remaining: 8.56s
# 14:	learn: 634.4441696	total: 1.48s	remaining: 8.4s
# 15:	learn: 614.3736046	total: 1.57s	remaining: 8.23s
# 16:	learn: 614.2196535	total: 1.61s	remaining: 7.88s
# 17:	learn: 585.9904340	total: 1.7s	remaining: 7.74s
# 18:	learn: 573.5179646	total: 1.78s	remaining: 7.58s
# 19:	learn: 557.2111805	total: 1.86s	remaining: 7.46s
# 20:	learn: 556.2515245	total: 1.92s	remaining: 7.23s
# 21:	learn: 547.8380996	total: 2.01s	remaining: 7.12s
# 22:	learn: 525.4946029	total: 2.09s	remaining: 6.99s
# 23:	learn: 525.3573356	total: 2.15s	remaining: 6.81s
# 24:	learn: 512.3813302	total: 2.23s	remaining: 6.7s
# 25:	learn: 501.9003249	total: 2.32s	remaining: 6.61s
# 26:	learn: 501.1089472	total: 2.4s	remaining: 6.49s
# 27:	learn: 491.8411800	total: 2.48s	remaining: 6.38s
# 28:	learn: 482.6915037	total: 2.57s	remaining: 6.29s
# 29:	learn: 472.4135017	total: 2.65s	remaining: 6.18s
# 30:	learn: 463.3496189	total: 2.73s	remaining: 6.08s
# 31:	learn: 443.9694511	total: 2.81s	remaining: 5.97s
# 32:	learn: 439.0891871	total: 2.9s	remaining: 5.88s
# 33:	learn: 431.8896810	total: 2.98s	remaining: 5.79s
# 34:	learn: 426.2926044	total: 3.07s	remaining: 5.7s
# 35:	learn: 420.3040501	total: 3.16s	remaining: 5.62s
# 36:	learn: 417.2524361	total: 3.25s	remaining: 5.54s
# 37:	learn: 413.1909112	total: 3.34s	remaining: 5.45s
# 38:	learn: 408.9943764	total: 3.43s	remaining: 5.36s
# 39:	learn: 405.5976060	total: 3.52s	remaining: 5.27s
# 40:	learn: 399.3168775	total: 3.6s	remaining: 5.18s
# 41:	learn: 394.8982025	total: 3.68s	remaining: 5.09s
# 42:	learn: 389.3217935	total: 3.77s	remaining: 4.99s
# 43:	learn: 375.6719014	total: 3.85s	remaining: 4.9s
# 44:	learn: 372.7830485	total: 3.93s	remaining: 4.81s
# 45:	learn: 369.6168136	total: 4.01s	remaining: 4.71s
# 46:	learn: 365.6431287	total: 4.1s	remaining: 4.62s
# 47:	learn: 363.4314129	total: 4.18s	remaining: 4.53s
# 48:	learn: 356.5633683	total: 4.27s	remaining: 4.44s
# 49:	learn: 354.1948722	total: 4.35s	remaining: 4.35s
# 50:	learn: 353.8204508	total: 4.4s	remaining: 4.23s
# 51:	learn: 351.6086184	total: 4.49s	remaining: 4.14s
# 52:	learn: 347.9141860	total: 4.57s	remaining: 4.05s
# 53:	learn: 339.8474609	total: 4.65s	remaining: 3.96s
# 54:	learn: 337.2838697	total: 4.73s	remaining: 3.87s
# 55:	learn: 333.7749754	total: 4.82s	remaining: 3.79s
# 56:	learn: 331.3708740	total: 4.91s	remaining: 3.7s
# 57:	learn: 329.5151799	total: 4.99s	remaining: 3.61s
# 58:	learn: 325.8112224	total: 5.07s	remaining: 3.52s
# 59:	learn: 323.5374734	total: 5.17s	remaining: 3.44s
# 60:	learn: 322.0259123	total: 5.25s	remaining: 3.35s
# 61:	learn: 314.4210833	total: 5.34s	remaining: 3.27s
# 62:	learn: 313.5387553	total: 5.42s	remaining: 3.19s
# 63:	learn: 309.2791093	total: 5.51s	remaining: 3.1s
# 64:	learn: 308.4856687	total: 5.59s	remaining: 3.01s
# 65:	learn: 307.0358971	total: 5.68s	remaining: 2.92s
# 66:	learn: 305.5483670	total: 5.76s	remaining: 2.84s
# 67:	learn: 304.6411119	total: 5.84s	remaining: 2.75s
# 68:	learn: 302.9772033	total: 5.93s	remaining: 2.66s
# 69:	learn: 296.0216738	total: 6.01s	remaining: 2.58s
# 70:	learn: 295.0937695	total: 6.1s	remaining: 2.49s
# 71:	learn: 294.1174837	total: 6.18s	remaining: 2.4s
# 72:	learn: 293.1684338	total: 6.27s	remaining: 2.32s
# 73:	learn: 291.9251614	total: 6.36s	remaining: 2.23s
# 74:	learn: 290.6107423	total: 6.44s	remaining: 2.15s
# 75:	learn: 290.0760499	total: 6.53s	remaining: 2.06s
# 76:	learn: 288.7107733	total: 6.61s	remaining: 1.97s
# 77:	learn: 285.7922663	total: 6.69s	remaining: 1.89s
# 78:	learn: 282.0468299	total: 6.78s	remaining: 1.8s
# 79:	learn: 278.2613785	total: 6.86s	remaining: 1.72s
# 80:	learn: 276.4229464	total: 6.95s	remaining: 1.63s
# 81:	learn: 275.8654099	total: 7.03s	remaining: 1.54s
# 82:	learn: 272.7492606	total: 7.12s	remaining: 1.46s
# 83:	learn: 271.3812071	total: 7.21s	remaining: 1.37s
# 84:	learn: 269.5802785	total: 7.3s	remaining: 1.29s
# 85:	learn: 267.6633273	total: 7.39s	remaining: 1.2s
# 86:	learn: 267.1206440	total: 7.47s	remaining: 1.12s
# 87:	learn: 263.2729073	total: 7.56s	remaining: 1.03s
# 88:	learn: 262.6970652	total: 7.64s	remaining: 944ms
# 89:	learn: 261.7882861	total: 7.72s	remaining: 858ms
# 90:	learn: 260.4946626	total: 7.8s	remaining: 772ms
# 91:	learn: 259.2174030	total: 7.88s	remaining: 686ms
# 92:	learn: 258.0344713	total: 7.97s	remaining: 600ms
# 93:	learn: 255.8554778	total: 8.05s	remaining: 514ms
# 94:	learn: 252.0875165	total: 8.13s	remaining: 428ms
# 95:	learn: 250.9879907	total: 8.22s	remaining: 343ms
# 96:	learn: 250.6080045	total: 8.3s	remaining: 257ms
# 97:	learn: 248.6842745	total: 8.38s	remaining: 171ms
# 98:	learn: 248.0888658	total: 8.47s	remaining: 85.5ms
# 99:	learn: 247.2698286	total: 8.55s	remaining: 0us
# Точность на обучающей выборке:  0.9992629416398486
# Точность на тестовой выборке:  0.9988310286429312

# %% [markdown]
# Как можно видеть, catboost справился лучше всего, но одиночное дерево тоже показало себя неплохо.
# Выводы, которые можно сделать: нужно контролировать глубину ветвления. В случае с catboost я использовал max_depth = 9 (на основе личного опыта часто это оптимальный параметр - это как байка от Андрея Карпатого о том, что лучший learning_rate для Adam - это 3*10^(-4); но кроме шуток, в рамках ДЗ я вновь убедился в своем наблюдении, попробовав несколько других значений).
# Любопытно, что в общем случае дерево выбрало самым главным параметром тип трансмиссии - но это тоже объяснимо: механическая коробка передач обычно стоит на относительно дешевых авто, для машин подороже существует большое число куда более сложных систем.
